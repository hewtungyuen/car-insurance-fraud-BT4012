# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from utils import *
sns.set()

# %%
df = pd.DataFrame([["One Class SVM",0.065,0.045] , ["Logistic",0.088,0.76], ["KNN",0.0841,0.7463], ["Decision Tree", 0.0974,0.970], ["Random Forest", 0.09,0.85], ["XGBoost",0.0592,1]], columns = ["Model", "Precision", "Recall"])
df.plot(x='Model',
        kind='bar',
        stacked=False,
        title='Model Performance when Maximizing Recall')
# Out:
# <AxesSubplot:title={'center':'Model Performance when Maximizing Recall'}, xlabel='Model'>

# %%
df = pd.DataFrame([["One Class SVM",0.054,0.43,0.078] , ["Logistic",0.082,0.85,0.30], ["KNN",0.1138,0.6642,0.3376], ["Decision Tree", 0.143,0.560, 0.362], ["Random Forest", 0.13,0.57,0.34], ["XGBoost",0.1466,0.70896,0.401], ["Voting Classifier", 0.153,0.731, 0.416]], columns = ["Model", "Precision", "Recall", "f_beta"])
df.plot(x='Model',
        kind='bar',
        stacked=False,
        title='Model Performance when Maximisng F_beta Score (beta = 2)')
# Out:
# <AxesSubplot:title={'center':'Model Performance when Maximisng F_beta Score (beta = 2)'}, xlabel='Model'>
