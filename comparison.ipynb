# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from utils import *
sns.set()

# %%
df = pd.DataFrame(
        [["One Class SVM",0.065,0.584], ["Logistic",0.083,0.889], ["KNN",0.071,0.821], ["Decision Tree", 0.077,0.694], ["Random Forest", 0.08,0.888], ["XGBoost",0.059,1]], columns = ["Model", "Precision", "Recall"])
df.plot(x='Model',
        kind='bar',
        stacked=False,
        title='Model Performance when Maximizing Recall')
# Out:
# <AxesSubplot: title={'center': 'Model Performance when Maximizing Recall'}, xlabel='Model'>

# %%
df = pd.DataFrame([["One Class SVM",0.065,0.587,0.206] , ["Logistic",0.083,0.888,0.301], ["KNN",0.073,0.761,0.263], ["Decision Tree", 0.093, 0.813, 0.319], ["Random Forest", 0.119,0.649,0.343], ["XGBoost",0.136,0.746,0.393], ["Voting Classifier", 0.153,0.731, 0.416]], columns = ["Model", "Precision", "Recall", "f_beta"])
df.plot(x='Model',
        kind='bar',
        stacked=False,
        title='Model Performance when Maximisng F_beta Score (beta = 2)')
# Out:
# <AxesSubplot: title={'center': 'Model Performance when Maximisng F_beta Score (beta = 2)'}, xlabel='Model'>
