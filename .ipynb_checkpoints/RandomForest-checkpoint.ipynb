# %%
import numpy as np
import pandas as pd

# For statistical tests
from scipy import stats

# For visualization
# %matplotlib notebook
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Show all columns
pd.set_option('display.max_columns', None)

# For text EDA
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from sklearn.linear_model import LinearRegression, LogisticRegression

from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# For entropy computation
from pyitlib import discrete_random_variable as drv


from imblearn.combine import SMOTEENN

import warnings
warnings.filterwarnings("ignore")

# %%
# Initiate dataframe
df_train = pd.read_csv('train.csv', index_col=None)
df_test = pd.read_csv('test.csv', index_col=None)
df_valid = pd.read_csv('valid.csv', index_col=None)

# %%
import optuna
from sklearn import linear_model
from sklearn import ensemble
from sklearn import datasets
from sklearn import model_selection

# %%
def get_confusion_matrix(actual, predicted, title):
    cf = confusion_matrix(actual, predicted)
    group_names = ['True Negative','False Positive','False Negative','True Positive'] 
    group_counts = ['{0:0.0f}'.format(value) for value in cf.flatten()] 

    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_counts)]
    labels = np.asarray(labels).reshape(2,2)

    s = sns.heatmap(cf, annot=labels, fmt='', cmap='Blues', xticklabels=['non fraud', 'fraud'], yticklabels=['non fraud', 'fraud'])
    s.set(xlabel='Predictions', ylabel='True Labels', title=title)
    return s

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = get_train_and_test_values(df_train, df_valid, df_test)

# %%
from collections import Counter
from imblearn.combine import SMOTEENN

smote_enn = SMOTEENN(random_state=0, sampling_strategy=0.6)
X_train_resampled, y_train_resampled = smote_enn.fit_resample(X_train, y_train)

print(sorted(Counter(y_train_resampled).items()))
print(sorted(Counter(y_test).items()))
print(sorted(Counter(y_valid).items()))
# Out:
# [(0, 6580), (1, 5946)]
# [(0, 2131), (1, 134)]
# [(0, 2131), (1, 134)]

# %% [markdown]
# ### Optuna Hyperparameter Tuning

# %% [markdown]
# #### Finding hyperparameter with the best recall

# %%
#Step 1. Define an objective function to be maximized.
def objective(trial):
    
    # Step 2. Setup values for the hyperparameters:
    rf_n_estimators = trial.suggest_int("n_estimators", 10, 1000)
    rf_max_depth = trial.suggest_int("max_depth", 2, 32, log=True)
    rf_min_samples_split = trial.suggest_int('min_samples_split', 2, 150)
    rf_min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 60)
    rf_bootstrap = trial.suggest_categorical("bootstrap", [True, False])
    rf_max_features = trial.suggest_categorical("max_features", ['auto', 'sqrt'])
    
    classifier_obj = ensemble.RandomForestClassifier(
        max_depth=rf_max_depth,
        n_estimators=rf_n_estimators,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        bootstrap = rf_bootstrap,
        max_features=rf_max_features,
        random_state = 0
    )
    
    cl_model = classifier_obj.fit(X_train_resampled,y_train_resampled)

    # Step 3: Scoring method:
    predictions = cl_model.predict(X_valid)
    return metrics.recall_score(y_valid, predictions)

# Step 4: Running it
study_recall = optuna.create_study(direction="maximize")
study_recall.optimize(objective, n_trials=100)
# Out:
# [I 2022-11-13 15:12:29,779] A new study created in memory with name: no-name-69cef19b-5a43-47de-a4cf-c9443526c37b
# [I 2022-11-13 15:12:38,349] Trial 0 finished with value: 0.5149253731343284 and parameters: {'n_estimators': 445, 'max_depth': 27, 'min_samples_split': 23, 'min_samples_leaf': 34, 'bootstrap': False, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.5149253731343284.
# [I 2022-11-13 15:12:41,607] Trial 1 finished with value: 0.6268656716417911 and parameters: {'n_estimators': 199, 'max_depth': 9, 'min_samples_split': 106, 'min_samples_leaf': 5, 'bootstrap': False, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.6268656716417911.
# [I 2022-11-13 15:12:57,804] Trial 2 finished with value: 0.5 and parameters: {'n_estimators': 891, 'max_depth': 20, 'min_samples_split': 75, 'min_samples_leaf': 26, 'bootstrap': False, 'max_features': 'auto'}. Best is trial 1 with value: 0.6268656716417911.
# [I 2022-11-13 15:13:01,066] Trial 3 finished with value: 0.6343283582089553 and parameters: {'n_estimators': 539, 'max_depth': 2, 'min_samples_split': 60, 'min_samples_leaf': 11, 'bootstrap': False, 'max_features': 'auto'}. Best is trial 3 with value: 0.6343283582089553.
# [I 2022-11-13 15:13:11,418] Trial 4 finished with value: 0.5373134328358209 and parameters: {'n_estimators': 595, 'max_depth': 14, 'min_samples_split': 122, 'min_samples_leaf': 49, 'bootstrap': False, 'max_features': 'auto'}. Best is trial 3 with value: 0.6343283582089553.
# [I 2022-11-13 15:13:20,261] Trial 5 finished with value: 0.44776119402985076 and parameters: {'n_estimators': 681, 'max_depth': 29, 'min_samples_split': 54, 'min_samples_leaf': 17, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 3 with value: 0.6343283582089553.
# [I 2022-11-13 15:13:24,822] Trial 6 finished with value: 0.6268656716417911 and parameters: {'n_estimators': 786, 'max_depth': 2, 'min_samples_split': 121, 'min_samples_leaf': 14, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 3 with value: 0.6343283582089553.
# [I 2022-11-13 15:13:29,129] Trial 7 finished with value: 0.7164179104477612 and parameters: {'n_estimators': 438, 'max_depth': 7, 'min_samples_split': 126, 'min_samples_leaf': 50, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 7 with value: 0.7164179104477612.
# [I 2022-11-13 15:13:29,645] Trial 8 finished with value: 0.6791044776119403 and parameters: {'n_estimators': 45, 'max_depth': 5, 'min_samples_split': 129, 'min_samples_leaf': 46, 'bootstrap': False, 'max_features': 'auto'}. Best is trial 7 with value: 0.7164179104477612.
# [I 2022-11-13 15:13:36,997] Trial 9 finished with value: 0.6940298507462687 and parameters: {'n_estimators': 968, 'max_depth': 4, 'min_samples_split': 122, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 7 with value: 0.7164179104477612.
# [I 2022-11-13 15:13:40,693] Trial 10 finished with value: 0.664179104477612 and parameters: {'n_estimators': 337, 'max_depth': 9, 'min_samples_split': 94, 'min_samples_leaf': 56, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 7 with value: 0.7164179104477612.
# [I 2022-11-13 15:13:47,770] Trial 11 finished with value: 0.6940298507462687 and parameters: {'n_estimators': 923, 'max_depth': 4, 'min_samples_split': 144, 'min_samples_leaf': 31, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 7 with value: 0.7164179104477612.
# [I 2022-11-13 15:13:50,372] Trial 12 finished with value: 0.7313432835820896 and parameters: {'n_estimators': 349, 'max_depth': 4, 'min_samples_split': 150, 'min_samples_leaf': 41, 'bootstrap': True, 'max_features': 'auto'}. Best is trial
 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 29, 'bootstrap': True, 'max_features': 'sqrt'}
# 	values: [0.8507462686567164]

# %%
rf_test2 = RandomForestClassifier(random_state=0)
rf_test2.set_params(**trial_recall.params)
rf_test2.set_params(**best)
rf_test2.fit(X_train_resampled,y_train_resampled)
# make predictions for test data
predictions = rf_test2.predict(X_valid)

# evaluate predictions
get_scores(y_valid, predictions)
# Out:
# Precision: 0.085
# Accuracy: 0.452
# Recall: 0.851
# F1: 0.155
# Fbeta: 0.304
# ROC AUC: 0.639
# PR AUC: 0.081

# %%
get_confusion_matrix(y_valid,predictions, "Tuned for recall")
# Out:
# <AxesSubplot:title={'center':'Tuned for recall'}, xlabel='Predictions', ylabel='True Labels'>

# %% [markdown]
# #### Finding hyperparameter with the best f2 score

# %%
#Step 1. Define an objective function to be maximized.
def objective(trial):
    
    # Step 2. Setup values for the hyperparameters:
    rf_n_estimators = trial.suggest_int("n_estimators", 10, 1000)
    rf_max_depth = trial.suggest_int("max_depth", 2, 32, log=True)
    rf_min_samples_split = trial.suggest_int('min_samples_split', 2, 150)
    rf_min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 60)
    rf_bootstrap = trial.suggest_categorical("bootstrap", [True, False])
    rf_max_features = trial.suggest_categorical("max_features", ['auto', 'sqrt'])
    
    classifier_obj = ensemble.RandomForestClassifier(
        max_depth=rf_max_depth,
        n_estimators=rf_n_estimators,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        bootstrap = rf_bootstrap,
        max_features=rf_max_features,
        random_state = 0
    )
    
    cl_model = classifier_obj.fit(X_train_resampled,y_train_resampled)

    # Step 3: Scoring method:
    predictions = cl_model.predict(X_valid)
    recall = metrics.recall_score(y_valid, predictions)
    fbeta = metrics.fbeta_score(y_valid, predictions, beta = 2)
    return fbeta

# Step 4: Running it
study_fbeta = optuna.create_study(directions=["maximize"])
study_fbeta.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-13 17:31:32,256] A new study created in memory with name: no-name-56ed7800-9019-482c-aa0d-6df6c44b5e3a
# [I 2022-11-13 17:31:36,912] Trial 0 finished with value: 0.26830808080808083 and parameters: {'n_estimators': 924, 'max_depth': 2, 'min_samples_split': 4, 'min_samples_leaf': 41, 'bootstrap': False, 'max_features': 'auto'}. Best is trial 0 with value: 0.26830808080808083.
# [I 2022-11-13 17:31:38,133] Trial 1 finished with value: 0.257703081232493 and parameters: {'n_estimators': 210, 'max_depth': 3, 'min_samples_split': 14, 'min_samples_leaf': 59, 'bootstrap': False, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.26830808080808083.
# [I 2022-11-13 17:31:38,935] Trial 2 finished with value: 0.2650602409638554 and parameters: {'n_estimators': 197, 'max_depth': 2, 'min_samples_split': 99, 'min_samples_leaf': 43, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.26830808080808083.
# [I 2022-11-13 17:31:44,749] Trial 3 finished with value: 0.2585365853658536 and parameters: {'n_estimators': 572, 'max_depth': 28, 'min_samples_split': 37, 'min_samples_leaf': 16, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.26830808080808083.
# [I 2022-11-13 17:31:57,462] Trial 4 finished with value: 0.30621172353455817 and parameters: {'n_estimators': 917, 'max_depth': 29, 'min_samples_split': 102, 'min_samples_leaf': 31, 'bootstrap': False, 'max_features': 'auto'}. Best is trial 4 with value: 0.30621172353455817.
# [I 2022-11-13 17:32:03,279] Trial 5 finished with value: 0.29311520109066125 and parameters: {'n_estimators': 691, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 24, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 4 with value: 0.30621172353455817.
# [I 2022-11-13 17:32:12,354] Trial 6 finished with value: 0.30873493975903615 and parameters: {'n_estimators': 985, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 42, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 6 with value: 0.30873493975903615.
# [I 2022-11-13 17:32:13,313] Trial 7 finished with value: 0.23391812865497075 and parameters: {'n_estimators': 92, 'max_depth': 20, 'min_samples_split': 42, 'min_samples_leaf': 20, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 6 with value: 0.30873493975903615.
# [I 2022-11-13 17:32:13,711] Trial 8 finished with value: 0.28616852146263905 and parameters: {'n_estimators': 71, 'max_depth': 3, 'min_samples_split': 59, 'min_samples_leaf': 24, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 6 with value: 0.30873493975903615.
# [I 2022-11-13 17:32:16,424] Trial 9 finished with value: 0.2644679527069073 and parameters: {'n_estimators': 534, 'max_depth': 2, 'min_samples_split': 19, 'min_samples_leaf': 21, 'bootstrap': False, 'max_features': 'auto'}. Best is trial 6 with value: 0.30873493975903615.
# [I 2022-11-13 17:32:25,197] Trial 10 finished with value: 0.3083700440528634 and parameters: {'n_estimators': 771, 'max_depth': 11, 'min_samples_split': 144, 'min_samples_leaf': 3, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 6 with value: 0.30873493975903615.
# [I 2022-11-13 17:32:33,943] Trial 11 finished with value: 0.32280701754385965 and parameters: {'n_estimators': 770, 'max_depth': 10, 'min_samples_split': 149, 'min_samples_leaf': 2, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:32:42,993] Trial 12 finished with value: 0.3127413127413128 and parameters: {'n_estimators': 997, 'max_depth': 13, 'min_samples_split': 149, 'min_samples_leaf': 3, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:32:48,432] Trial 13 finished with value: 0.2841596130592503 and parameters: {'n_estimators': 785, 'max_depth': 6, 'min_samples_split': 144, 'min_samples_leaf': 3, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:32:51,181] Trial 14 finished with value: 0.28942705256940343 and parameters: {'n_estimators': 389, 'max_depth': 6, 'min_samples_split': 119, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:32:58,967] Trial 15 finished with value: 0.3012519561815336 and parameters: {'n_estimators': 818, 'max_depth': 14, 'min_samples_split': 125, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:33:03,991] Trial 16 finished with value: 0.29546946815495734 and parameters: {'n_estimators': 637, 'max_depth': 8, 'min_samples_split': 84, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:33:13,829] Trial 17 finished with value: 0.31011045029736617 and parameters: {'n_estimators': 994, 'max_depth': 17, 'min_samples_split': 126, 'min_samples_leaf': 2, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:33:18,566] Trial 18 finished with value: 0.30149051490514905 and parameters: {'n_estimators': 398, 'max_depth': 10, 'min_samples_split': 144, 'min_samples_leaf': 32, 'bootstrap': False, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:33:24,021] Trial 19 finished with value: 0.28419182948490224 and parameters: {'n_estimators': 852, 'max_depth': 5, 'min_samples_split': 114, 'min_samples_leaf': 14, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:33:28,234] Trial 20 finished with value: 0.2772861356932153 and parameters: {'n_estimators': 697, 'max_depth': 4, 'min_samples_split': 77, 'min_samples_leaf': 7, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:33:36,690] Trial 21 finished with value: 0.31355932203389825 and parameters: {'n_estimators': 982, 'max_depth': 19, 'min_samples_split': 131, 'min_samples_leaf': 3, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:33:44,432] Trial 22 finished with value: 0.3109452736318408 and parameters: {'n_estimators': 912, 'max_depth': 21, 'min_samples_split': 149, 'min_samples_leaf': 7, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:33:51,603] Trial 23 finished with value: 0.31001589825119236 and parameters: {'n_estimators': 867, 'max_depth': 16, 'min_samples_split': 132, 'min_samples_leaf': 15, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:33:58,653] Trial 24 finished with value: 0.31091829356471445 and parameters: {'n_estimators': 718, 'max_depth': 10, 'min_samples_split': 104, 'min_samples_leaf': 6, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:34:07,899] Trial 25 finished with value: 0.295836376917458 and parameters: {'n_estimators': 959, 'max_depth': 23, 'min_samples_split': 135, 'min_samples_leaf': 59, 'bootstrap': True, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:34:23,153] Trial 26 finished with value: 0.2876608629825889 and parameters: {'n_estimators': 998, 'max_depth': 11, 'min_samples_split': 133, 'min_samples_leaf': 53, 'bootstrap': False, 'max_features': 'auto'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:34:33,632] Trial 27 finished with value: 0.3129952456418384 and parameters: {'n_estimators': 860, 'max_depth': 14, 'min_samples_split': 114, 'min_samples_leaf': 18, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:34:39,108] Trial 28 finished with value: 0.29042386185243335 and parameters: {'n_estimators': 451, 'max_depth': 32, 'min_samples_split': 91, 'min_samples_leaf': 27, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:34:51,976] Trial 29 finished with value: 0.3021523178807947 and parameters: {'n_estimators': 889, 'max_depth': 17, 'min_samples_split': 114, 'min_samples_leaf': 38, 'bootstrap': False, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:34:59,742] Trial 30 finished with value: 0.31655844155844154 and parameters: {'n_estimators': 771, 'max_depth': 24, 'min_samples_split': 113, 'min_samples_leaf': 18, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:35:07,119] Trial 31 finished with value: 0.3005686433793664 and parameters: {'n_estimators': 761, 'max_depth': 25, 'min_samples_split': 107, 'min_samples_leaf': 17, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:35:13,414] Trial 32 finished with value: 0.30377668308702793 and parameters: {'n_estimators': 637, 'max_depth': 18, 'min_samples_split': 123, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:35:21,523] Trial 33 finished with value: 0.31223980016652786 and parameters: {'n_estimators': 813, 'max_depth': 23, 'min_samples_split': 90, 'min_samples_leaf': 20, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:35:31,291] Trial 34 finished with value: 0.3027950310559006 and parameters: {'n_estimators': 861, 'max_depth': 14, 'min_samples_split': 66, 'min_samples_leaf': 37, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:35:39,803] Trial 35 finished with value: 0.3032217308907138 and parameters: {'n_estimators': 611, 'max_depth': 8, 'min_samples_split': 135, 'min_samples_leaf': 28, 'bootstrap': False, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:35:51,106] Trial 36 finished with value: 0.3095843935538592 and parameters: {'n_estimators': 930, 'max_depth': 25, 'min_samples_split': 111, 'min_samples_leaf': 7, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:35:59,350] Trial 37 finished with value: 0.2986217457886677 and parameters: {'n_estimators': 750, 'max_depth': 19, 'min_samples_split': 100, 'min_samples_leaf': 47, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:36:08,849] Trial 38 finished with value: 0.30090684253915917 and parameters: {'n_estimators': 825, 'max_depth': 31, 'min_samples_split': 138, 'min_samples_leaf': 18, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:36:19,706] Trial 39 finished with value: 0.28089887640449435 and parameters: {'n_estimators': 676, 'max_depth': 15, 'min_samples_split': 93, 'min_samples_leaf': 33, 'bootstrap': False, 'max_features': 'sqrt'}. Best is trial 11 with value: 0.32280701754385965.
# [I 2022-11-13 17:36:22,705] Trial 40 finished with value: 0.32623626373626374 and parameters: {'n_estimators': 254, 'max_depth': 12, 'min_samples_split': 120, 'min_samples_leaf': 24, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.
# [I 2022-11-13 17:36:26,086] Trial 41 finished with value: 0.3213545266067726 and parameters: {'n_estimators': 298, 'max_depth': 12, 'min_samples_split': 118, 'min_samples_leaf': 24, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.
# [I 2022-11-13 17:36:28,974] Trial 42 finished with value: 0.3205574912891986 and parameters: {'n_estimators': 259, 'max_depth': 12, 'min_samples_split': 128, 'min_samples_leaf': 24, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.
# [I 2022-11-13 17:36:31,702] Trial 43 finished with value: 0.30180460485376476 and parameters: {'n_estimators': 264, 'max_depth': 9, 'min_samples_split': 122, 'min_samples_leaf': 24, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.
# [I 2022-11-13 17:36:34,368] Trial 44 finished with value: 0.3028118240807498 and parameters: {'n_estimators': 244, 'max_depth': 12, 'min_samples_split': 140, 'min_samples_leaf': 28, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.
# [I 2022-11-13 17:36:35,876] Trial 45 finished with value: 0.3082614056720098 and parameters: {'n_estimators': 158, 'max_depth': 7, 'min_samples_split': 118, 'min_samples_leaf': 24, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.
# [I 2022-11-13 17:36:39,349] Trial 46 finished with value: 0.306047197640118 and parameters: {'n_estimators': 312, 'max_depth': 12, 'min_samples_split': 127, 'min_samples_leaf': 22, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.
# [I 2022-11-13 17:36:40,561] Trial 47 finished with value: 0.31442241968557755 and parameters: {'n_estimators': 120, 'max_depth': 9, 'min_samples_split': 27, 'min_samples_leaf': 26, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.
# [I 2022-11-13 17:36:43,645] Trial 48 finished with value: 0.2987804878048781 and parameters: {'n_estimators': 319, 'max_depth': 7, 'min_samples_split': 48, 'min_samples_leaf': 31, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.
# [I 2022-11-13 17:36:45,170] Trial 49 finished with value: 0.27332144979203804 and parameters: {'n_estimators': 190, 'max_depth': 5, 'min_samples_split': 106, 'min_samples_leaf': 35, 'bootstrap': True, 'max_features': 'sqrt'}. Best is trial 40 with value: 0.32623626373626374.

# %%
trial_fbeta = study_fbeta.best_trial

print(f"Trial of Choice: ")
print(f"\tnumber: {trial_fbeta.number}")
print(f"\tparams: {trial_fbeta.params}")
print(f"\tvalues: {trial_fbeta.values}")
# Out:
# Trial of Choice:
# 	number: 40
# 	params: {'n_estimators': 254, 'max_depth': 12, 'min_samples_split': 120, 'min_samples_leaf': 24, 'bootstrap': True, 'max_features': 'sqrt'}
# 	values: [0.32623626373626374]

# %%
rf_test = RandomForestClassifier(random_state=0)
rf_test.set_params(**trial_fbeta.params)
rf_test.fit(X_train_resampled,y_train_resampled)

# make predictions for test data
predictions = rf_test.predict(X_valid)

# evaluate predictions
get_scores(y_valid, predictions)
# Out:
# Precision: 0.124
# Accuracy: 0.732
# Recall: 0.582
# F1: 0.205
# Fbeta: 0.335
# ROC AUC: 0.662
# PR AUC: 0.097

# %%
#Confusion Matrix
get_confusion_matrix(y_valid,predictions, "Tuned for fbeta")
# Out:
# <AxesSubplot:title={'center':'Tuned for fbeta'}, xlabel='Predictions', ylabel='True Labels'>

# %% [markdown]
# ### SHAP

# %%
import shap
# Fits the explainer
explainer = shap.Explainer(rf_test2.predict, X_train_resampled, seed=0)
shap_values = explainer(X_train_resampled[1:1000,:])
# Out:
# Permutation explainer: 1000it [00:35, 22.34it/s]

# %%
#creating a feature list
features  = df_train.drop('FraudFound_P', axis=1).columns.tolist()
feature_dict = {}
for num in range(53):
    feature_key = "f" + str(num)
    feature_dict[feature_key] = features[num]
print(feature_dict)
# Out:
# {'f0': 'MonthClaimed', 'f1': 'VehiclePrice', 'f2': 'Deductible', 'f3': 'DriverRating', 'f4': 'Days_Policy_Accident', 'f5': 'Days_Policy_Claim', 'f6': 'PastNumberOfClaims', 'f7': 'AgeOfVehicle', 'f8': 'AgeOfPolicyHolder', 'f9': 'NumberOfSuppliments', 'f10': 'AddressChange_Claim', 'f11': 'NumberOfCars', 'f12': 'Year', 'f13': 'AccidentArea_IsUrban', 'f14': 'Sex_IsMale', 'f15': 'Fault_IsPolicyholder', 'f16': 'PoliceReportFiled_IsYes', 'f17': 'WitnessPresent_IsYes', 'f18': 'AgentType_IsExternal', 'f19': 'isWithinAgeRange_IsTrue', 'f20': 'Make_Accura', 'f21': 'Make_BMW', 'f22': 'Make_Chevrolet', 'f23': 'Make_Dodge', 'f24': 'Make_Ford', 'f25': 'Make_Honda', 'f26': 'Make_Jaguar', 'f27': 'Make_Lexus', 'f28': 'Make_Mazda', 'f29': 'Make_Mecedes', 'f30': 'Make_Mercury', 'f31': 'Make_Nisson', 'f32': 'Make_Pontiac', 'f33': 'Make_Porche', 'f34': 'Make_Saab', 'f35': 'Make_Saturn', 'f36': 'Make_Toyota', 'f37': 'Make_VW', 'f38': 'MaritalStatus_Divorced', 'f39': 'MaritalStatus_Married', 'f40': 'MaritalStatus_Single', 'f41': 'MaritalStatus_Widow', 'f42': 'PolicyType_Sedan - All Perils', 'f43': 'PolicyType_Sedan - Collision', 'f44': 'PolicyType_Sedan - Liability', 'f45': 'PolicyType_Sport - All Perils', 'f46': 'PolicyType_Sport - Collision', 'f47': 'PolicyType_Utility - All Perils', 'f48': 'PolicyType_Utility - Collision', 'f49': 'PolicyType_Utility - Liability', 'f50': 'Make_Ferrari', 'f51': 'PolicyType_Sport - Liability', 'f52': 'Normalised_Age'}

# %%
X_display = df_train.drop('FraudFound_P', axis=1)

# %%
shap.summary_plot(shap_values, X_display, plot_type="bar", feature_names=features)

# %%
shap.summary_plot(shap_values, X_train_resampled[1:1000,:],features)
